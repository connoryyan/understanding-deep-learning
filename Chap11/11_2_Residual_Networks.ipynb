# %% [markdown]
# <a href="https://colab.research.google.com/github/connoryyan/understanding-deep-learning/blob/main/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-lc_ml48o
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-lc_ml48o
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=a548a2dc3611e0e8d4d4167b8e30340d24389dbd66fbb70e98de1e69bb897207
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nifxl78p/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.569903, train error 61.83,  val loss 1.646713, percent error 65.30
# Epoch     1, train loss 1.306666, train error 48.55,  val loss 1.422924, percent error 56.30
# Epoch     2, train loss 1.128121, train error 41.83,  val loss 1.344253, percent error 53.10
# Epoch     3, train loss 0.971380, train error 35.47,  val loss 1.273412, percent error 49.70
# Epoch     4, train loss 0.863809, train error 32.10,  val loss 1.202727, percent error 47.10
# Epoch     5, train loss 0.727571, train error 26.93,  val loss 1.170151, percent error 42.80
# Epoch     6, train loss 0.620684, train error 21.82,  val loss 1.080612, percent error 41.30
# Epoch     7, train loss 0.522055, train error 17.97,  val loss 1.024287, percent error 39.10
# Epoch     8, train loss 0.482396, train error 17.30,  val loss 1.107551, percent error 39.20
# Epoch     9, train loss 0.402335, train error 14.53,  val loss 1.079507, percent error 38.60
# Epoch    10, train loss 0.376850, train error 13.03,  val loss 1.075205, percent error 38.90
# Epoch    11, train loss 0.311968, train error 9.78,  val loss 1.083329, percent error 36.50
# Epoch    12, train loss 0.250768, train error 8.65,  val loss 1.204540, percent error 35.00
# Epoch    13, train loss 0.210773, train error 6.60,  val loss 1.245066, percent error 35.20
# Epoch    14, train loss 0.188288, train error 6.12,  val loss 1.147540, percent error 34.30
# Epoch    15, train loss 0.191118, train error 6.35,  val loss 1.393618, percent error 37.80
# Epoch    16, train loss 0.149908, train error 4.43,  val loss 1.394509, percent error 37.20
# Epoch    17, train loss 0.191823, train error 7.00,  val loss 1.447493, percent error 35.20
# Epoch    18, train loss 0.210244, train error 7.45,  val loss 1.407318, percent error 37.20
# Epoch    19, train loss 0.149853, train error 4.90,  val loss 1.478861, percent error 36.80
# Epoch    20, train loss 0.043650, train error 0.40,  val loss 1.318778, percent error 32.60
# Epoch    21, train loss 0.022025, train error 0.03,  val loss 1.347300, percent error 32.20
# Epoch    22, train loss 0.015439, train error 0.00,  val loss 1.371135, percent error 31.10
# Epoch    23, train loss 0.012739, train error 0.00,  val loss 1.410609, percent error 31.80
# Epoch    24, train loss 0.010268, train error 0.00,  val loss 1.439489, percent error 31.70
# Epoch    25, train loss 0.009100, train error 0.00,  val loss 1.468213, percent error 31.70
# Epoch    26, train loss 0.007939, train error 0.00,  val loss 1.493441, percent error 31.60
# Epoch    27, train loss 0.007125, train error 0.00,  val loss 1.515333, percent error 31.50
# Epoch    28, train loss 0.006648, train error 0.00,  val loss 1.533117, percent error 31.50
# Epoch    29, train loss 0.005986, train error 0.00,  val loss 1.551217, percent error 31.40
# Epoch    30, train loss 0.005565, train error 0.00,  val loss 1.574223, percent error 31.70
# Epoch    31, train loss 0.005169, train error 0.00,  val loss 1.584921, percent error 31.50
# Epoch    32, train loss 0.004832, train error 0.00,  val loss 1.602143, percent error 31.60
# Epoch    33, train loss 0.004568, train error 0.00,  val loss 1.618090, percent error 31.70
# Epoch    34, train loss 0.004348, train error 0.00,  val loss 1.626880, percent error 31.70
# Epoch    35, train loss 0.004075, train error 0.00,  val loss 1.643990, percent error 31.20
# Epoch    36, train loss 0.003833, train error 0.00,  val loss 1.653760, percent error 31.30
# Epoch    37, train loss 0.003651, train error 0.00,  val loss 1.666537, percent error 31.40
# Epoch    38, train loss 0.003475, train error 0.00,  val loss 1.674564, percent error 31.30
# Epoch    39, train loss 0.003317, train error 0.00,  val loss 1.686949, percent error 31.00
# Epoch    40, train loss 0.003239, train error 0.00,  val loss 1.691530, percent error 31.20
# Epoch    41, train loss 0.003169, train error 0.00,  val loss 1.697910, percent error 31.00
# Epoch    42, train loss 0.003104, train error 0.00,  val loss 1.701135, percent error 31.30
# Epoch    43, train loss 0.003039, train error 0.00,  val loss 1.707746, percent error 31.10
# Epoch    44, train loss 0.002977, train error 0.00,  val loss 1.710935, percent error 31.10
# Epoch    45, train loss 0.002919, train error 0.00,  val loss 1.715948, percent error 31.20
# Epoch    46, train loss 0.002866, train error 0.00,  val loss 1.722373, percent error 31.10
# Epoch    47, train loss 0.002809, train error 0.00,  val loss 1.725952, percent error 31.20
# Epoch    48, train loss 0.002756, train error 0.00,  val loss 1.729023, percent error 31.20
# Epoch    49, train loss 0.002706, train error 0.00,  val loss 1.734153, percent error 31.10
# Epoch    50, train loss 0.002658, train error 0.00,  val loss 1.738143, percent error 31.20
# Epoch    51, train loss 0.002611, train error 0.00,  val loss 1.743194, percent error 31.20
# Epoch    52, train loss 0.002567, train error 0.00,  val loss 1.747186, percent error 31.10
# Epoch    53, train loss 0.002522, train error 0.00,  val loss 1.751097, percent error 31.20
# Epoch    54, train loss 0.002480, train error 0.00,  val loss 1.754954, percent error 31.30
# Epoch    55, train loss 0.002440, train error 0.00,  val loss 1.760334, percent error 31.10
# Epoch    56, train loss 0.002399, train error 0.00,  val loss 1.763023, percent error 31.20
# Epoch    57, train loss 0.002361, train error 0.00,  val loss 1.766643, percent error 31.10
# Epoch    58, train loss 0.002323, train error 0.00,  val loss 1.771110, percent error 31.10
# Epoch    59, train loss 0.002287, train error 0.00,  val loss 1.775901, percent error 31.10
# Epoch    60, train loss 0.002268, train error 0.00,  val loss 1.777373, percent error 31.10
# Epoch    61, train loss 0.002251, train error 0.00,  val loss 1.778904, percent error 31.10
# Epoch    62, train loss 0.002234, train error 0.00,  val loss 1.780579, percent error 31.20
# Epoch    63, train loss 0.002217, train error 0.00,  val loss 1.782957, percent error 31.10
# Epoch    64, train loss 0.002200, train error 0.00,  val loss 1.784259, percent error 31.10
# Epoch    65, train loss 0.002184, train error 0.00,  val loss 1.786236, percent error 31.10
# Epoch    66, train loss 0.002168, train error 0.00,  val loss 1.787808, percent error 31.20
# Epoch    67, train loss 0.002152, train error 0.00,  val loss 1.789644, percent error 31.10
# Epoch    68, train loss 0.002136, train error 0.00,  val loss 1.791360, percent error 31.20
# Epoch    69, train loss 0.002121, train error 0.00,  val loss 1.792999, percent error 31.20
# Epoch    70, train loss 0.002106, train error 0.00,  val loss 1.794913, percent error 31.20
# Epoch    71, train loss 0.002091, train error 0.00,  val loss 1.796900, percent error 31.20
# Epoch    72, train loss 0.002076, train error 0.00,  val loss 1.798476, percent error 31.20
# Epoch    73, train loss 0.002061, train error 0.00,  val loss 1.800055, percent error 31.20
# Epoch    74, train loss 0.002047, train error 0.00,  val loss 1.801708, percent error 31.20
# Epoch    75, train loss 0.002033, train error 0.00,  val loss 1.803642, percent error 31.30
# Epoch    76, train loss 0.002018, train error 0.00,  val loss 1.805251, percent error 31.30
# Epoch    77, train loss 0.002005, train error 0.00,  val loss 1.806952, percent error 31.30
# Epoch    78, train loss 0.001991, train error 0.00,  val loss 1.807788, percent error 31.30
# Epoch    79, train loss 0.001977, train error 0.00,  val loss 1.810134, percent error 31.30
# Epoch    80, train loss 0.001971, train error 0.00,  val loss 1.810965, percent error 31.30
# Epoch    81, train loss 0.001964, train error 0.00,  val loss 1.811789, percent error 31.30
# Epoch    82, train loss 0.001957, train error 0.00,  val loss 1.812411, percent error 31.30
# Epoch    83, train loss 0.001951, train error 0.00,  val loss 1.813338, percent error 31.30
# Epoch    84, train loss 0.001944, train error 0.00,  val loss 1.814257, percent error 31.30
# Epoch    85, train loss 0.001938, train error 0.00,  val loss 1.815062, percent error 31.30
# Epoch    86, train loss 0.001931, train error 0.00,  val loss 1.815711, percent error 31.30
# Epoch    87, train loss 0.001925, train error 0.00,  val loss 1.816702, percent error 31.30
# Epoch    88, train loss 0.001919, train error 0.00,  val loss 1.817393, percent error 31.30
# Epoch    89, train loss 0.001913, train error 0.00,  val loss 1.817811, percent error 31.30
# Epoch    90, train loss 0.001906, train error 0.00,  val loss 1.818753, percent error 31.30
# Epoch    91, train loss 0.001900, train error 0.00,  val loss 1.819661, percent error 31.30
# Epoch    92, train loss 0.001894, train error 0.00,  val loss 1.820318, percent error 31.30
# Epoch    93, train loss 0.001888, train error 0.00,  val loss 1.821214, percent error 31.30
# Epoch    94, train loss 0.001882, train error 0.00,  val loss 1.822100, percent error 31.30
# Epoch    95, train loss 0.001876, train error 0.00,  val loss 1.822732, percent error 31.30
# Epoch    96, train loss 0.001869, train error 0.00,  val loss 1.823379, percent error 31.30
# Epoch    97, train loss 0.001864, train error 0.00,  val loss 1.824210, percent error 31.30
# Epoch    98, train loss 0.001858, train error 0.00,  val loss 1.824879, percent error 31.20
# Epoch    99, train loss 0.001852, train error 0.00,  val loss 1.825716, percent error 31.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
#
# Network without Residual has better performance (31.3% compared to 38%) and converges at almost the same time (20 epochs) with current initialization.
