# %% [markdown]
# <a href="https://colab.research.google.com/github/connoryyan/understanding-deep-learning/blob/main/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-cl497rfu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-cl497rfu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=cc07742d5ce2a59cc0eada04c767247a675637ef29e950f2a19c514007a1c7e4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1r46cr4r/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 120   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=120, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=120, out_features=120, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.6)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.709004, train error 66.47,  test loss 1.822725, test error 72.50
# Epoch     1, train loss 1.573734, train error 61.67,  test loss 1.709889, test error 66.70
# Epoch     2, train loss 1.428337, train error 53.20,  test loss 1.592985, test error 63.60
# Epoch     3, train loss 1.343382, train error 49.53,  test loss 1.513427, test error 60.90
# Epoch     4, train loss 1.250599, train error 44.25,  test loss 1.440709, test error 57.30
# Epoch     5, train loss 1.173234, train error 40.22,  test loss 1.388462, test error 56.20
# Epoch     6, train loss 1.119959, train error 39.15,  test loss 1.351114, test error 52.40
# Epoch     7, train loss 1.077044, train error 37.08,  test loss 1.324237, test error 52.20
# Epoch     8, train loss 1.005744, train error 34.15,  test loss 1.283792, test error 50.90
# Epoch     9, train loss 0.956971, train error 31.78,  test loss 1.272755, test error 49.30
# Epoch    10, train loss 0.917621, train error 30.65,  test loss 1.225863, test error 48.90
# Epoch    11, train loss 0.893916, train error 29.07,  test loss 1.226125, test error 49.60
# Epoch    12, train loss 0.874567, train error 28.80,  test loss 1.220322, test error 49.00
# Epoch    13, train loss 0.851085, train error 27.35,  test loss 1.202864, test error 48.10
# Epoch    14, train loss 0.829899, train error 26.32,  test loss 1.196341, test error 47.70
# Epoch    15, train loss 0.814523, train error 25.97,  test loss 1.192547, test error 46.50
# Epoch    16, train loss 0.792383, train error 25.50,  test loss 1.180276, test error 47.00
# Epoch    17, train loss 0.774746, train error 24.60,  test loss 1.171400, test error 46.10
# Epoch    18, train loss 0.753222, train error 23.38,  test loss 1.180429, test error 47.00
# Epoch    19, train loss 0.743733, train error 23.53,  test loss 1.185803, test error 45.90
# Epoch    20, train loss 0.726575, train error 22.47,  test loss 1.157559, test error 46.30
# Epoch    21, train loss 0.712519, train error 21.93,  test loss 1.153465, test error 46.80
# Epoch    22, train loss 0.704927, train error 21.15,  test loss 1.147084, test error 45.10
# Epoch    23, train loss 0.700318, train error 21.88,  test loss 1.158912, test error 45.90
# Epoch    24, train loss 0.687144, train error 20.62,  test loss 1.155601, test error 46.40
# Epoch    25, train loss 0.681242, train error 20.85,  test loss 1.159423, test error 46.20
# Epoch    26, train loss 0.670561, train error 20.47,  test loss 1.154642, test error 46.30
# Epoch    27, train loss 0.661128, train error 19.95,  test loss 1.148673, test error 45.90
# Epoch    28, train loss 0.654166, train error 19.82,  test loss 1.142112, test error 45.00
# Epoch    29, train loss 0.647052, train error 19.32,  test loss 1.154032, test error 45.60
# Epoch    30, train loss 0.640640, train error 18.95,  test loss 1.148602, test error 45.00
# Epoch    31, train loss 0.636558, train error 19.10,  test loss 1.144558, test error 45.10
# Epoch    32, train loss 0.632128, train error 18.70,  test loss 1.140434, test error 45.50
# Epoch    33, train loss 0.629128, train error 18.47,  test loss 1.141572, test error 45.10
# Epoch    34, train loss 0.624653, train error 18.25,  test loss 1.140356, test error 45.50
# Epoch    35, train loss 0.621304, train error 18.20,  test loss 1.146431, test error 45.20
# Epoch    36, train loss 0.619463, train error 18.53,  test loss 1.147366, test error 44.90
# Epoch    37, train loss 0.613775, train error 18.07,  test loss 1.141075, test error 45.20
# Epoch    38, train loss 0.609868, train error 17.80,  test loss 1.141869, test error 44.90
# Epoch    39, train loss 0.605011, train error 17.32,  test loss 1.143201, test error 45.00
# Epoch    40, train loss 0.602839, train error 17.47,  test loss 1.141933, test error 45.20
# Epoch    41, train loss 0.601023, train error 17.15,  test loss 1.141290, test error 45.10
# Epoch    42, train loss 0.599363, train error 17.35,  test loss 1.142871, test error 44.80
# Epoch    43, train loss 0.597327, train error 17.05,  test loss 1.142495, test error 44.80
# Epoch    44, train loss 0.595754, train error 17.12,  test loss 1.138205, test error 44.60
# Epoch    45, train loss 0.593817, train error 17.05,  test loss 1.141654, test error 44.90
# Epoch    46, train loss 0.591819, train error 16.97,  test loss 1.138464, test error 44.60
# Epoch    47, train loss 0.589973, train error 16.80,  test loss 1.142215, test error 44.50
# Epoch    48, train loss 0.588226, train error 16.82,  test loss 1.139813, test error 43.80
# Epoch    49, train loss 0.586587, train error 16.88,  test loss 1.139634, test error 43.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# It is not a good idea, as using the test set to adjust the network will not help with generalization. A validation set should be used to evaluate the performance of different hyperparameters before testing on the test set.
