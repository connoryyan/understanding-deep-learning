# %% [markdown]
# <a href="https://colab.research.google.com/github/connoryyan/understanding-deep-learning/blob/main/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-qis08_gx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-qis08_gx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=4511e2cf3ece9d67e44f4128794cf662c6af9a305ed6a4ed3042697ba0d85746
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dqr7exyx/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# * About 4000
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# * Somewhere before 4000
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# * 4000

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.297592, train error 89.28,  test loss 2.301985, test error 89.07
# Epoch   100, train loss 1.907590, train error 72.53,  test loss 1.759867, test error 69.60
# Epoch   200, train loss 1.873182, train error 69.60,  test loss 1.708685, test error 66.07
# Epoch   300, train loss 1.864761, train error 68.57,  test loss 1.698140, test error 65.32
# Epoch   400, train loss 1.860482, train error 68.15,  test loss 1.692902, test error 65.62
# Epoch   500, train loss 1.861700, train error 68.43,  test loss 1.687106, test error 66.62
# Epoch   600, train loss 1.858431, train error 68.78,  test loss 1.700347, test error 66.50
# Epoch   700, train loss 1.852770, train error 68.60,  test loss 1.696277, test error 66.38
# Epoch   800, train loss 1.857014, train error 69.18,  test loss 1.712249, test error 67.18
# Epoch   900, train loss 1.851537, train error 68.10,  test loss 1.715242, test error 66.82
# Training model with   4 hidden variables
# Epoch     0, train loss 2.284359, train error 87.10,  test loss 2.285631, test error 87.30
# Epoch   100, train loss 1.739476, train error 63.05,  test loss 1.560426, test error 59.83
# Epoch   200, train loss 1.726166, train error 63.47,  test loss 1.540973, test error 59.47
# Epoch   300, train loss 1.718181, train error 62.80,  test loss 1.532911, test error 58.78
# Epoch   400, train loss 1.714349, train error 62.40,  test loss 1.524980, test error 58.60
# Epoch   500, train loss 1.711498, train error 62.62,  test loss 1.521585, test error 59.22
# Epoch   600, train loss 1.711339, train error 62.62,  test loss 1.523947, test error 58.97
# Epoch   700, train loss 1.710525, train error 61.85,  test loss 1.518417, test error 59.42
# Epoch   800, train loss 1.711910, train error 62.65,  test loss 1.530322, test error 59.50
# Epoch   900, train loss 1.708954, train error 62.88,  test loss 1.527255, test error 59.35
# Training model with   6 hidden variables
# Epoch     0, train loss 2.255782, train error 84.20,  test loss 2.243143, test error 83.20
# Epoch   100, train loss 1.716247, train error 62.95,  test loss 1.571340, test error 60.40
# Epoch   200, train loss 1.662999, train error 59.38,  test loss 1.518102, test error 58.55
# Epoch   300, train loss 1.662286, train error 59.40,  test loss 1.521442, test error 58.53
# Epoch   400, train loss 1.637872, train error 57.80,  test loss 1.489808, test error 55.88
# Epoch   500, train loss 1.621521, train error 56.67,  test loss 1.483254, test error 55.70
# Epoch   600, train loss 1.618802, train error 56.88,  test loss 1.469489, test error 54.90
# Epoch   700, train loss 1.612060, train error 55.72,  test loss 1.460019, test error 55.42
# Epoch   800, train loss 1.595019, train error 54.88,  test loss 1.429146, test error 53.90
# Epoch   900, train loss 1.581343, train error 53.85,  test loss 1.401826, test error 53.40
# Training model with   8 hidden variables
# Epoch     0, train loss 2.212543, train error 80.82,  test loss 2.184954, test error 78.75
# Epoch   100, train loss 1.650414, train error 58.28,  test loss 1.511282, test error 58.62
# Epoch   200, train loss 1.593161, train error 56.67,  test loss 1.451493, test error 56.30
# Epoch   300, train loss 1.576969, train error 56.20,  test loss 1.450840, test error 54.92
# Epoch   400, train loss 1.561971, train error 55.47,  test loss 1.457310, test error 55.17
# Epoch   500, train loss 1.549406, train error 55.25,  test loss 1.453810, test error 54.78
# Epoch   600, train loss 1.544961, train error 54.72,  test loss 1.459200, test error 55.22
# Epoch   700, train loss 1.538728, train error 54.55,  test loss 1.461618, test error 54.88
# Epoch   800, train loss 1.532435, train error 54.97,  test loss 1.455404, test error 54.67
# Epoch   900, train loss 1.532130, train error 54.78,  test loss 1.458101, test error 54.53
# Training model with  10 hidden variables
# Epoch     0, train loss 2.253576, train error 83.57,  test loss 2.248406, test error 84.45
# Epoch   100, train loss 1.540025, train error 54.75,  test loss 1.391110, test error 53.08
# Epoch   200, train loss 1.465798, train error 50.05,  test loss 1.325630, test error 50.33
# Epoch   300, train loss 1.407589, train error 48.20,  test loss 1.259856, test error 45.67
# Epoch   400, train loss 1.393331, train error 47.55,  test loss 1.274244, test error 47.15
# Epoch   500, train loss 1.384927, train error 47.08,  test loss 1.301403, test error 47.67
# Epoch   600, train loss 1.374079, train error 46.20,  test loss 1.294495, test error 46.88
# Epoch   700, train loss 1.363762, train error 46.83,  test loss 1.294981, test error 47.15
# Epoch   800, train loss 1.363645, train error 46.55,  test loss 1.316721, test error 47.78
# Epoch   900, train loss 1.365766, train error 46.95,  test loss 1.314415, test error 48.50
# Training model with  14 hidden variables
# Epoch     0, train loss 2.157518, train error 79.88,  test loss 2.128982, test error 78.53
# Epoch   100, train loss 1.502884, train error 52.45,  test loss 1.421548, test error 54.72
# Epoch   200, train loss 1.409493, train error 47.75,  test loss 1.378288, test error 51.28
# Epoch   300, train loss 1.349711, train error 46.03,  test loss 1.335141, test error 48.72
# Epoch   400, train loss 1.315750, train error 45.30,  test loss 1.338553, test error 48.05
# Epoch   500, train loss 1.293653, train error 44.15,  test loss 1.326330, test error 47.60
# Epoch   600, train loss 1.287193, train error 44.58,  test loss 1.323858, test error 47.72
# Epoch   700, train loss 1.275415, train error 44.03,  test loss 1.342061, test error 47.95
# Epoch   800, train loss 1.269022, train error 43.25,  test loss 1.343636, test error 48.30
# Epoch   900, train loss 1.268312, train error 43.17,  test loss 1.346193, test error 47.97
# Training model with  18 hidden variables
# Epoch     0, train loss 2.220633, train error 81.95,  test loss 2.200556, test error 82.05
# Epoch   100, train loss 1.427980, train error 47.97,  test loss 1.402945, test error 52.45
# Epoch   200, train loss 1.316705, train error 44.50,  test loss 1.415468, test error 51.97
# Epoch   300, train loss 1.259812, train error 42.83,  test loss 1.442094, test error 51.70
# Epoch   400, train loss 1.233291, train error 42.47,  test loss 1.466200, test error 51.78
# Epoch   500, train loss 1.223762, train error 41.75,  test loss 1.512065, test error 53.15
# Epoch   600, train loss 1.197953, train error 40.67,  test loss 1.526078, test error 53.42
# Epoch   700, train loss 1.176868, train error 39.35,  test loss 1.533409, test error 52.70
# Epoch   800, train loss 1.169779, train error 40.28,  test loss 1.573039, test error 53.45
# Epoch   900, train loss 1.164279, train error 40.00,  test loss 1.588635, test error 53.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.271272, train error 84.90,  test loss 2.283280, test error 84.85
# Epoch   100, train loss 1.236292, train error 41.85,  test loss 1.323676, test error 48.38
# Epoch   200, train loss 1.115661, train error 37.67,  test loss 1.411000, test error 49.10
# Epoch   300, train loss 1.056417, train error 36.08,  test loss 1.503799, test error 50.62
# Epoch   400, train loss 1.039900, train error 35.85,  test loss 1.556613, test error 51.25
# Epoch   500, train loss 1.009351, train error 35.03,  test loss 1.620384, test error 52.03
# Epoch   600, train loss 0.995805, train error 34.55,  test loss 1.663976, test error 51.95
# Epoch   700, train loss 0.991986, train error 35.00,  test loss 1.703964, test error 52.12
# Epoch   800, train loss 0.993044, train error 34.82,  test loss 1.729312, test error 52.05
# Epoch   900, train loss 0.982273, train error 34.35,  test loss 1.779476, test error 53.40
# Training model with  26 hidden variables
# Epoch     0, train loss 2.217951, train error 83.62,  test loss 2.195531, test error 82.50
# Epoch   100, train loss 1.177631, train error 38.85,  test loss 1.275655, test error 47.05
# Epoch   200, train loss 1.021287, train error 33.20,  test loss 1.361897, test error 47.85
# Epoch   300, train loss 0.949812, train error 30.40,  test loss 1.469637, test error 48.50
# Epoch   400, train loss 0.903466, train error 30.12,  test loss 1.607184, test error 50.40
# Epoch   500, train loss 0.889759, train error 29.20,  test loss 1.723748, test error 50.55
# Epoch   600, train loss 0.855723, train error 28.75,  test loss 1.809279, test error 50.97
# Epoch   700, train loss 0.833364, train error 27.85,  test loss 1.847321, test error 51.03
# Epoch   800, train loss 0.839980, train error 28.30,  test loss 1.952477, test error 52.22
# Epoch   900, train loss 0.806885, train error 26.40,  test loss 1.987942, test error 52.30
# Training model with  30 hidden variables
# Epoch     0, train loss 2.132542, train error 78.05,  test loss 2.102094, test error 78.03
# Epoch   100, train loss 1.129704, train error 36.55,  test loss 1.375677, test error 49.55
# Epoch   200, train loss 0.952259, train error 32.12,  test loss 1.537661, test error 51.22
# Epoch   300, train loss 0.838491, train error 28.10,  test loss 1.714291, test error 52.30
# Epoch   400, train loss 0.772494, train error 26.55,  test loss 1.924390, test error 53.58
# Epoch   500, train loss 0.735512, train error 25.72,  test loss 2.111548, test error 53.80
# Epoch   600, train loss 0.716774, train error 24.45,  test loss 2.287004, test error 55.12
# Epoch   700, train loss 0.680108, train error 23.10,  test loss 2.392680, test error 55.15
# Epoch   800, train loss 0.686239, train error 24.25,  test loss 2.534197, test error 55.83
# Epoch   900, train loss 0.638111, train error 21.80,  test loss 2.642589, test error 54.72
# Training model with  35 hidden variables
# Epoch     0, train loss 2.129243, train error 78.35,  test loss 2.093839, test error 77.93
# Epoch   100, train loss 1.019398, train error 33.70,  test loss 1.368219, test error 49.33
# Epoch   200, train loss 0.800673, train error 26.40,  test loss 1.619951, test error 50.78
# Epoch   300, train loss 0.699467, train error 22.93,  test loss 2.011153, test error 53.30
# Epoch   400, train loss 0.626146, train error 20.97,  test loss 2.330304, test error 53.70
# Epoch   500, train loss 0.591901, train error 20.62,  test loss 2.686945, test error 56.47
# Epoch   600, train loss 0.569517, train error 19.93,  test loss 2.993664, test error 56.08
# Epoch   700, train loss 0.518443, train error 17.75,  test loss 3.254847, test error 57.33
# Epoch   800, train loss 0.514187, train error 17.95,  test loss 3.483501, test error 55.72
# Epoch   900, train loss 0.475589, train error 16.88,  test loss 3.736321, test error 56.85
# Training model with  40 hidden variables
# Epoch     0, train loss 2.111629, train error 78.15,  test loss 2.080083, test error 78.57
# Epoch   100, train loss 0.926812, train error 29.60,  test loss 1.434116, test error 49.25
# Epoch   200, train loss 0.656080, train error 20.88,  test loss 1.913822, test error 53.12
# Epoch   300, train loss 0.515010, train error 16.35,  test loss 2.526680, test error 54.22
# Epoch   400, train loss 0.442499, train error 14.15,  test loss 3.310233, test error 56.33
# Epoch   500, train loss 0.356738, train error 11.57,  test loss 4.019333, test error 57.20
# Epoch   600, train loss 0.273890, train error 8.75,  test loss 4.747490, test error 57.75
# Epoch   700, train loss 0.265080, train error 8.60,  test loss 5.645600, test error 57.95
# Epoch   800, train loss 0.252699, train error 8.50,  test loss 6.286720, test error 57.90
# Epoch   900, train loss 0.253503, train error 9.10,  test loss 7.014894, test error 58.95
# Training model with  45 hidden variables
# Epoch     0, train loss 2.104712, train error 79.78,  test loss 2.056323, test error 77.97
# Epoch   100, train loss 0.839449, train error 26.93,  test loss 1.533386, test error 51.55
# Epoch   200, train loss 0.502161, train error 16.05,  test loss 2.247401, test error 52.55
# Epoch   300, train loss 0.363634, train error 11.90,  test loss 3.322749, test error 55.80
# Epoch   400, train loss 0.260466, train error 8.70,  test loss 4.536353, test error 55.97
# Epoch   500, train loss 0.179558, train error 6.15,  test loss 5.862693, test error 56.33
# Epoch   600, train loss 0.133616, train error 4.28,  test loss 6.993593, test error 55.97
# Epoch   700, train loss 0.189885, train error 6.55,  test loss 8.163627, test error 57.25
# Epoch   800, train loss 0.011352, train error 0.03,  test loss 9.083869, test error 56.88
# Epoch   900, train loss 0.006661, train error 0.03,  test loss 9.684420, test error 57.08
# Training model with  50 hidden variables
# Epoch     0, train loss 2.060971, train error 75.95,  test loss 2.027328, test error 76.03
# Epoch   100, train loss 0.718677, train error 22.45,  test loss 1.585105, test error 51.53
# Epoch   200, train loss 0.344095, train error 10.50,  test loss 2.758406, test error 54.70
# Epoch   300, train loss 0.145401, train error 3.60,  test loss 4.351478, test error 55.85
# Epoch   400, train loss 0.025594, train error 0.00,  test loss 5.999453, test error 56.38
# Epoch   500, train loss 0.012202, train error 0.00,  test loss 6.949659, test error 56.20
# Epoch   600, train loss 0.007581, train error 0.00,  test loss 7.585199, test error 56.20
# Epoch   700, train loss 0.005510, train error 0.00,  test loss 8.065948, test error 56.62
# Epoch   800, train loss 0.004260, train error 0.00,  test loss 8.434756, test error 56.47
# Epoch   900, train loss 0.003440, train error 0.00,  test loss 8.750793, test error 56.35
# Training model with  55 hidden variables
# Epoch     0, train loss 2.065065, train error 76.50,  test loss 1.998202, test error 76.45
# Epoch   100, train loss 0.629605, train error 18.30,  test loss 1.648582, test error 50.85
# Epoch   200, train loss 0.239180, train error 6.28,  test loss 2.894089, test error 53.92
# Epoch   300, train loss 0.051756, train error 0.25,  test loss 4.569082, test error 55.65
# Epoch   400, train loss 0.014836, train error 0.00,  test loss 5.619260, test error 55.45
# Epoch   500, train loss 0.008335, train error 0.00,  test loss 6.232674, test error 55.47
# Epoch   600, train loss 0.005661, train error 0.00,  test loss 6.673219, test error 55.55
# Epoch   700, train loss 0.004200, train error 0.00,  test loss 7.011086, test error 55.47
# Epoch   800, train loss 0.003327, train error 0.00,  test loss 7.288041, test error 55.65
# Epoch   900, train loss 0.002736, train error 0.00,  test loss 7.515549, test error 55.62
# Training model with  60 hidden variables
# Epoch     0, train loss 2.031323, train error 76.70,  test loss 1.992355, test error 77.07
# Epoch   100, train loss 0.534383, train error 15.28,  test loss 1.823722, test error 54.12
# Epoch   200, train loss 0.134403, train error 2.05,  test loss 3.491877, test error 55.22
# Epoch   300, train loss 0.021943, train error 0.00,  test loss 4.963164, test error 55.83
# Epoch   400, train loss 0.010304, train error 0.00,  test loss 5.721655, test error 56.00
# Epoch   500, train loss 0.006359, train error 0.00,  test loss 6.216303, test error 56.12
# Epoch   600, train loss 0.004544, train error 0.00,  test loss 6.588616, test error 56.15
# Epoch   700, train loss 0.003483, train error 0.00,  test loss 6.874549, test error 56.22
# Epoch   800, train loss 0.002811, train error 0.00,  test loss 7.112545, test error 56.17
# Epoch   900, train loss 0.002322, train error 0.00,  test loss 7.318928, test error 56.12
# Training model with  70 hidden variables
# Epoch     0, train loss 2.011832, train error 74.35,  test loss 1.947624, test error 75.15
# Epoch   100, train loss 0.378714, train error 10.15,  test loss 1.880236, test error 50.75
# Epoch   200, train loss 0.034398, train error 0.00,  test loss 3.390198, test error 51.75
# Epoch   300, train loss 0.011418, train error 0.00,  test loss 4.173441, test error 51.95
# Epoch   400, train loss 0.006202, train error 0.00,  test loss 4.592327, test error 52.28
# Epoch   500, train loss 0.004174, train error 0.00,  test loss 4.891922, test error 52.53
# Epoch   600, train loss 0.003075, train error 0.00,  test loss 5.116527, test error 52.45
# Epoch   700, train loss 0.002415, train error 0.00,  test loss 5.299536, test error 52.80
# Epoch   800, train loss 0.001973, train error 0.00,  test loss 5.453044, test error 52.80
# Epoch   900, train loss 0.001661, train error 0.00,  test loss 5.585423, test error 52.72
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019477, train error 74.20,  test loss 1.978317, test error 75.03
# Epoch   100, train loss 0.201399, train error 2.82,  test loss 2.148360, test error 51.53
# Epoch   200, train loss 0.018414, train error 0.00,  test loss 3.402258, test error 52.08
# Epoch   300, train loss 0.007489, train error 0.00,  test loss 3.930471, test error 52.42
# Epoch   400, train loss 0.004481, train error 0.00,  test loss 4.241118, test error 52.47
# Epoch   500, train loss 0.003113, train error 0.00,  test loss 4.468630, test error 52.70
# Epoch   600, train loss 0.002348, train error 0.00,  test loss 4.643103, test error 52.65
# Epoch   700, train loss 0.001866, train error 0.00,  test loss 4.784819, test error 52.55
# Epoch   800, train loss 0.001537, train error 0.00,  test loss 4.905610, test error 52.50
# Epoch   900, train loss 0.001301, train error 0.00,  test loss 5.009877, test error 52.67
# Training model with  90 hidden variables
# Epoch     0, train loss 2.013014, train error 74.70,  test loss 1.974131, test error 75.35
# Epoch   100, train loss 0.130269, train error 0.75,  test loss 2.131541, test error 50.65
# Epoch   200, train loss 0.014451, train error 0.00,  test loss 3.084327, test error 51.33
# Epoch   300, train loss 0.006429, train error 0.00,  test loss 3.486104, test error 51.40
# Epoch   400, train loss 0.003940, train error 0.00,  test loss 3.739371, test error 51.30
# Epoch   500, train loss 0.002774, train error 0.00,  test loss 3.920805, test error 51.40
# Epoch   600, train loss 0.002110, train error 0.00,  test loss 4.061335, test error 51.33
# Epoch   700, train loss 0.001688, train error 0.00,  test loss 4.178291, test error 51.38
# Epoch   800, train loss 0.001397, train error 0.00,  test loss 4.276660, test error 51.40
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.361219, test error 51.45
# Training model with 100 hidden variables
# Epoch     0, train loss 2.002918, train error 74.70,  test loss 1.924356, test error 73.78
# Epoch   100, train loss 0.099674, train error 0.35,  test loss 2.216964, test error 50.35
# Epoch   200, train loss 0.012736, train error 0.00,  test loss 3.104229, test error 50.65
# Epoch   300, train loss 0.005818, train error 0.00,  test loss 3.473696, test error 50.80
# Epoch   400, train loss 0.003599, train error 0.00,  test loss 3.705894, test error 50.92
# Epoch   500, train loss 0.002549, train error 0.00,  test loss 3.874158, test error 51.03
# Epoch   600, train loss 0.001949, train error 0.00,  test loss 4.006160, test error 51.10
# Epoch   700, train loss 0.001566, train error 0.00,  test loss 4.114783, test error 51.25
# Epoch   800, train loss 0.001298, train error 0.00,  test loss 4.206742, test error 51.42
# Epoch   900, train loss 0.001105, train error 0.00,  test loss 4.285928, test error 51.45
# Training model with 120 hidden variables
# Epoch     0, train loss 1.986761, train error 73.22,  test loss 1.920949, test error 72.93
# Epoch   100, train loss 0.052705, train error 0.03,  test loss 2.325011, test error 50.40
# Epoch   200, train loss 0.009327, train error 0.00,  test loss 2.974497, test error 51.00
# Epoch   300, train loss 0.004656, train error 0.00,  test loss 3.269500, test error 50.90
# Epoch   400, train loss 0.002968, train error 0.00,  test loss 3.458699, test error 50.92
# Epoch   500, train loss 0.002145, train error 0.00,  test loss 3.597384, test error 50.97
# Epoch   600, train loss 0.001656, train error 0.00,  test loss 3.709116, test error 50.83
# Epoch   700, train loss 0.001339, train error 0.00,  test loss 3.799895, test error 50.85
# Epoch   800, train loss 0.001118, train error 0.00,  test loss 3.878413, test error 50.75
# Epoch   900, train loss 0.000956, train error 0.00,  test loss 3.947286, test error 50.90
# Training model with 140 hidden variables
# Epoch     0, train loss 1.968851, train error 72.97,  test loss 1.902943, test error 72.55
# Epoch   100, train loss 0.034851, train error 0.00,  test loss 2.212614, test error 49.22
# Epoch   200, train loss 0.007938, train error 0.00,  test loss 2.691277, test error 49.17
# Epoch   300, train loss 0.004101, train error 0.00,  test loss 2.919213, test error 49.22
# Epoch   400, train loss 0.002668, train error 0.00,  test loss 3.071465, test error 49.42
# Epoch   500, train loss 0.001945, train error 0.00,  test loss 3.184622, test error 49.38
# Epoch   600, train loss 0.001513, train error 0.00,  test loss 3.273943, test error 49.33
# Epoch   700, train loss 0.001230, train error 0.00,  test loss 3.348393, test error 49.28
# Epoch   800, train loss 0.001030, train error 0.00,  test loss 3.412025, test error 49.30
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.467994, test error 49.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.945701, train error 71.53,  test loss 1.883623, test error 71.65
# Epoch   100, train loss 0.028112, train error 0.00,  test loss 2.147741, test error 49.17
# Epoch   200, train loss 0.007096, train error 0.00,  test loss 2.554270, test error 49.53
# Epoch   300, train loss 0.003754, train error 0.00,  test loss 2.756991, test error 49.42
# Epoch   400, train loss 0.002469, train error 0.00,  test loss 2.891296, test error 49.55
# Epoch   500, train loss 0.001812, train error 0.00,  test loss 2.990333, test error 49.50
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 3.070988, test error 49.50
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.138600, test error 49.42
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.195202, test error 49.33
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.245212, test error 49.35
# Training model with 180 hidden variables
# Epoch     0, train loss 1.924792, train error 70.82,  test loss 1.857531, test error 71.88
# Epoch   100, train loss 0.023275, train error 0.00,  test loss 2.001195, test error 47.35
# Epoch   200, train loss 0.006411, train error 0.00,  test loss 2.334810, test error 47.45
# Epoch   300, train loss 0.003456, train error 0.00,  test loss 2.502256, test error 47.53
# Epoch   400, train loss 0.002295, train error 0.00,  test loss 2.615838, test error 47.60
# Epoch   500, train loss 0.001692, train error 0.00,  test loss 2.701095, test error 47.47
# Epoch   600, train loss 0.001326, train error 0.00,  test loss 2.770273, test error 47.50
# Epoch   700, train loss 0.001084, train error 0.00,  test loss 2.827770, test error 47.55
# Epoch   800, train loss 0.000912, train error 0.00,  test loss 2.876616, test error 47.53
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 2.919747, test error 47.55
# Training model with 200 hidden variables
# Epoch     0, train loss 1.910551, train error 69.70,  test loss 1.816698, test error 70.32
# Epoch   100, train loss 0.020931, train error 0.00,  test loss 2.009366, test error 48.25
# Epoch   200, train loss 0.006046, train error 0.00,  test loss 2.316448, test error 48.40
# Epoch   300, train loss 0.003296, train error 0.00,  test loss 2.473835, test error 48.35
# Epoch   400, train loss 0.002200, train error 0.00,  test loss 2.580220, test error 48.25
# Epoch   500, train loss 0.001627, train error 0.00,  test loss 2.660435, test error 48.12
# Epoch   600, train loss 0.001278, train error 0.00,  test loss 2.724405, test error 48.15
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.777992, test error 48.05
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.824277, test error 48.15
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.864926, test error 47.97
# Training model with 250 hidden variables
# Epoch     0, train loss 1.906986, train error 69.75,  test loss 1.825512, test error 71.57
# Epoch   100, train loss 0.017203, train error 0.00,  test loss 1.878008, test error 46.40
# Epoch   200, train loss 0.005331, train error 0.00,  test loss 2.121115, test error 46.25
# Epoch   300, train loss 0.002966, train error 0.00,  test loss 2.252126, test error 46.38
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.339819, test error 46.42
# Epoch   500, train loss 0.001489, train error 0.00,  test loss 2.408140, test error 46.28
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.462385, test error 46.28
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.508194, test error 46.33
# Epoch   800, train loss 0.000815, train error 0.00,  test loss 2.547701, test error 46.30
# Epoch   900, train loss 0.000703, train error 0.00,  test loss 2.582061, test error 46.20
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876064, train error 66.93,  test loss 1.808012, test error 68.85
# Epoch   100, train loss 0.014428, train error 0.00,  test loss 1.851404, test error 46.92
# Epoch   200, train loss 0.004796, train error 0.00,  test loss 2.070599, test error 46.75
# Epoch   300, train loss 0.002719, train error 0.00,  test loss 2.190542, test error 46.72
# Epoch   400, train loss 0.001854, train error 0.00,  test loss 2.271845, test error 46.62
# Epoch   500, train loss 0.001388, train error 0.00,  test loss 2.334308, test error 46.38
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.384967, test error 46.50
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.427487, test error 46.47
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.464158, test error 46.42
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.496390, test error 46.40
# Training model with 400 hidden variables
# Epoch     0, train loss 1.891029, train error 68.82,  test loss 1.833442, test error 71.68
# Epoch   100, train loss 0.011551, train error 0.00,  test loss 1.813553, test error 46.78
# Epoch   200, train loss 0.004115, train error 0.00,  test loss 1.993798, test error 46.62
# Epoch   300, train loss 0.002384, train error 0.00,  test loss 2.093629, test error 46.70
# Epoch   400, train loss 0.001643, train error 0.00,  test loss 2.163870, test error 46.65
# Epoch   500, train loss 0.001239, train error 0.00,  test loss 2.217817, test error 46.62
# Epoch   600, train loss 0.000987, train error 0.00,  test loss 2.261916, test error 46.62
# Epoch   700, train loss 0.000816, train error 0.00,  test loss 2.298880, test error 46.75
# Epoch   800, train loss 0.000693, train error 0.00,  test loss 2.330713, test error 46.70
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.358624, test error 46.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
