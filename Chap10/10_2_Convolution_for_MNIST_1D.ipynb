# %% [markdown]
# <a href="https://colab.research.google.com/github/connoryyan/understanding-deep-learning/blob/main/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-0kmd18a_
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-0kmd18a_
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=d2d212c789fa6c96459579688baec6cd2b64bcd5ba6beeb395d29805eb09518e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ckuko476/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
model = nn.Sequential(
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
  nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding='valid'),
# 2. ReLU
  nn.ReLU(),
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
# 4. ReLU
  nn.ReLU(),
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
# 6. ReLU
  nn.ReLU(),
# 7. Flatten (converts 4x15) to length 60
  nn.Flatten(),
# 8. Linear layer (input size = 60, output size = 10)
  nn.Linear(60, 10)
)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.140995, train error 80.78,  val loss 2.139139, percent error 82.00
# Epoch     1, train loss 1.533063, train error 60.45,  val loss 1.546666, percent error 63.30
# Epoch     2, train loss 1.517630, train error 62.83,  val loss 1.522707, percent error 64.60
# Epoch     3, train loss 1.288430, train error 51.83,  val loss 1.322830, percent error 55.50
# Epoch     4, train loss 1.272139, train error 52.55,  val loss 1.311416, percent error 54.50
# Epoch     5, train loss 1.220984, train error 50.58,  val loss 1.228130, percent error 51.70
# Epoch     6, train loss 1.159485, train error 48.67,  val loss 1.198080, percent error 50.80
# Epoch     7, train loss 0.979196, train error 40.17,  val loss 1.023356, percent error 43.20
# Epoch     8, train loss 0.917949, train error 37.67,  val loss 0.951716, percent error 42.10
# Epoch     9, train loss 0.842081, train error 34.10,  val loss 0.893475, percent error 38.60
# Epoch    10, train loss 0.821830, train error 32.35,  val loss 0.886840, percent error 35.70
# Epoch    11, train loss 0.732605, train error 28.80,  val loss 0.809397, percent error 30.40
# Epoch    12, train loss 0.631665, train error 24.18,  val loss 0.689222, percent error 26.60
# Epoch    13, train loss 0.562671, train error 21.15,  val loss 0.624663, percent error 23.50
# Epoch    14, train loss 0.623373, train error 24.80,  val loss 0.681904, percent error 25.20
# Epoch    15, train loss 0.529660, train error 19.40,  val loss 0.585330, percent error 21.60
# Epoch    16, train loss 0.439517, train error 16.93,  val loss 0.540847, percent error 19.20
# Epoch    17, train loss 0.439293, train error 15.93,  val loss 0.526054, percent error 18.90
# Epoch    18, train loss 0.348049, train error 12.57,  val loss 0.461638, percent error 17.20
# Epoch    19, train loss 0.369402, train error 13.65,  val loss 0.488845, percent error 18.60
# Epoch    20, train loss 0.298497, train error 10.78,  val loss 0.421547, percent error 14.10
# Epoch    21, train loss 0.279633, train error 9.70,  val loss 0.397932, percent error 14.50
# Epoch    22, train loss 0.265311, train error 9.78,  val loss 0.437529, percent error 15.00
# Epoch    23, train loss 0.269692, train error 9.55,  val loss 0.404272, percent error 13.20
# Epoch    24, train loss 0.233179, train error 8.22,  val loss 0.391633, percent error 14.00
# Epoch    25, train loss 0.226587, train error 7.60,  val loss 0.404806, percent error 13.60
# Epoch    26, train loss 0.214132, train error 7.65,  val loss 0.410275, percent error 12.70
# Epoch    27, train loss 0.204602, train error 6.95,  val loss 0.373962, percent error 11.40
# Epoch    28, train loss 0.219450, train error 8.12,  val loss 0.400223, percent error 13.00
# Epoch    29, train loss 0.205882, train error 7.32,  val loss 0.404224, percent error 12.70
# Epoch    30, train loss 0.168605, train error 5.35,  val loss 0.352173, percent error 11.30
# Epoch    31, train loss 0.200338, train error 7.40,  val loss 0.390471, percent error 12.50
# Epoch    32, train loss 0.150543, train error 4.82,  val loss 0.376110, percent error 11.80
# Epoch    33, train loss 0.181299, train error 6.22,  val loss 0.392900, percent error 12.40
# Epoch    34, train loss 0.158424, train error 5.53,  val loss 0.393576, percent error 11.90
# Epoch    35, train loss 0.174871, train error 6.28,  val loss 0.416567, percent error 13.10
# Epoch    36, train loss 0.135859, train error 4.38,  val loss 0.366082, percent error 11.00
# Epoch    37, train loss 0.146486, train error 4.97,  val loss 0.367260, percent error 10.30
# Epoch    38, train loss 0.140190, train error 4.82,  val loss 0.367323, percent error 10.70
# Epoch    39, train loss 0.130975, train error 4.35,  val loss 0.344973, percent error 9.60
# Epoch    40, train loss 0.109323, train error 3.72,  val loss 0.348537, percent error 10.60
# Epoch    41, train loss 0.101236, train error 3.22,  val loss 0.360252, percent error 10.40
# Epoch    42, train loss 0.097444, train error 2.82,  val loss 0.359174, percent error 10.20
# Epoch    43, train loss 0.094189, train error 2.72,  val loss 0.356648, percent error 9.90
# Epoch    44, train loss 0.093861, train error 2.93,  val loss 0.355268, percent error 11.10
# Epoch    45, train loss 0.099086, train error 3.12,  val loss 0.374503, percent error 10.40
# Epoch    46, train loss 0.094643, train error 2.85,  val loss 0.370129, percent error 9.60
# Epoch    47, train loss 0.091983, train error 2.80,  val loss 0.364397, percent error 10.90
# Epoch    48, train loss 0.093915, train error 3.10,  val loss 0.358500, percent error 10.10
# Epoch    49, train loss 0.089191, train error 2.88,  val loss 0.364061, percent error 10.60
# Epoch    50, train loss 0.105764, train error 3.40,  val loss 0.395007, percent error 11.30
# Epoch    51, train loss 0.085077, train error 2.50,  val loss 0.376089, percent error 10.60
# Epoch    52, train loss 0.078333, train error 2.22,  val loss 0.369133, percent error 9.60
# Epoch    53, train loss 0.079202, train error 2.45,  val loss 0.370300, percent error 10.20
# Epoch    54, train loss 0.077300, train error 2.32,  val loss 0.373572, percent error 9.80
# Epoch    55, train loss 0.086381, train error 2.70,  val loss 0.390696, percent error 10.20
# Epoch    56, train loss 0.081027, train error 2.55,  val loss 0.387892, percent error 9.50
# Epoch    57, train loss 0.074672, train error 2.20,  val loss 0.382283, percent error 10.40
# Epoch    58, train loss 0.069507, train error 2.15,  val loss 0.366204, percent error 10.10
# Epoch    59, train loss 0.071012, train error 2.22,  val loss 0.377606, percent error 10.20
# Epoch    60, train loss 0.070611, train error 2.07,  val loss 0.386297, percent error 10.50
# Epoch    61, train loss 0.063345, train error 1.72,  val loss 0.379159, percent error 9.60
# Epoch    62, train loss 0.064006, train error 1.72,  val loss 0.385561, percent error 9.40
# Epoch    63, train loss 0.060844, train error 1.65,  val loss 0.386833, percent error 9.90
# Epoch    64, train loss 0.062023, train error 1.65,  val loss 0.387926, percent error 9.50
# Epoch    65, train loss 0.062629, train error 1.60,  val loss 0.396074, percent error 9.30
# Epoch    66, train loss 0.058785, train error 1.47,  val loss 0.388910, percent error 9.80
# Epoch    67, train loss 0.057715, train error 1.50,  val loss 0.386477, percent error 9.80
# Epoch    68, train loss 0.058854, train error 1.53,  val loss 0.387405, percent error 9.30
# Epoch    69, train loss 0.057283, train error 1.47,  val loss 0.391353, percent error 9.40
# Epoch    70, train loss 0.055737, train error 1.47,  val loss 0.392377, percent error 9.70
# Epoch    71, train loss 0.056638, train error 1.47,  val loss 0.392491, percent error 9.90
# Epoch    72, train loss 0.058925, train error 1.62,  val loss 0.398448, percent error 10.20
# Epoch    73, train loss 0.055345, train error 1.40,  val loss 0.395121, percent error 9.70
# Epoch    74, train loss 0.054599, train error 1.22,  val loss 0.397153, percent error 9.30
# Epoch    75, train loss 0.052756, train error 1.30,  val loss 0.402984, percent error 9.80
# Epoch    76, train loss 0.053426, train error 1.18,  val loss 0.401039, percent error 10.00
# Epoch    77, train loss 0.052777, train error 1.28,  val loss 0.401070, percent error 9.80
# Epoch    78, train loss 0.052234, train error 1.30,  val loss 0.404489, percent error 9.70
# Epoch    79, train loss 0.052857, train error 1.10,  val loss 0.406902, percent error 10.10
# Epoch    80, train loss 0.050653, train error 1.22,  val loss 0.404048, percent error 9.70
# Epoch    81, train loss 0.049838, train error 1.07,  val loss 0.405508, percent error 9.90
# Epoch    82, train loss 0.049349, train error 1.18,  val loss 0.405223, percent error 10.00
# Epoch    83, train loss 0.049074, train error 1.10,  val loss 0.404991, percent error 9.40
# Epoch    84, train loss 0.048834, train error 1.10,  val loss 0.407075, percent error 9.90
# Epoch    85, train loss 0.048291, train error 1.03,  val loss 0.407150, percent error 9.60
# Epoch    86, train loss 0.050048, train error 1.12,  val loss 0.413650, percent error 10.00
# Epoch    87, train loss 0.047918, train error 1.10,  val loss 0.409763, percent error 9.70
# Epoch    88, train loss 0.048395, train error 1.07,  val loss 0.411466, percent error 9.60
# Epoch    89, train loss 0.047242, train error 1.03,  val loss 0.410440, percent error 9.60
# Epoch    90, train loss 0.047255, train error 0.97,  val loss 0.408583, percent error 9.80
# Epoch    91, train loss 0.046702, train error 1.00,  val loss 0.409778, percent error 9.40
# Epoch    92, train loss 0.046723, train error 0.95,  val loss 0.410637, percent error 9.60
# Epoch    93, train loss 0.046534, train error 1.00,  val loss 0.412118, percent error 10.00
# Epoch    94, train loss 0.046267, train error 1.03,  val loss 0.412718, percent error 9.40
# Epoch    95, train loss 0.046244, train error 1.05,  val loss 0.413394, percent error 9.60
# Epoch    96, train loss 0.045532, train error 1.03,  val loss 0.412762, percent error 9.40
# Epoch    97, train loss 0.045353, train error 0.97,  val loss 0.414950, percent error 9.90
# Epoch    98, train loss 0.045511, train error 0.97,  val loss 0.414672, percent error 9.70
# Epoch    99, train loss 0.044817, train error 0.95,  val loss 0.416015, percent error 9.50
